# %%
</>Python

# リスト
array = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

# ディクショナリ
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# 水曜日の天気を出力
print(array[2])
print(dictionary["wed"])
# Out:
#   File "/tmp/ipykernel_6686/427879252.py", line 12
#     print(f"{area}"㎠)
#                    ^
# SyntaxError: invalid character '㎠' (U+33A0)
